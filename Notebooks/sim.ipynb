# %%
import sys
import os
sys.path.append("/data/shared/fangzy/project/spMAE/github_code/spMAE/spMAE")
import wandb
import torch
import numpy as np
import scanpy as sc
import pytorch_lightning as pl
from dataloader import spDataModule, lsiTransformer, apply_sgc_pure, TFIDF, process_adata_for_training
from model import spMAE_Lightning
from pytorch_lightning.loggers import WandbLogger
from evaluate import evaluate, db_sil, pas_chaos
from util import mclust_R, dopca

# %%
i = 0

# %%
path = "/data/shared/fangzy/results/spMAE/results/"
pl.seed_everything(42, workers=True)
adata = sc.read_h5ad(f"/data/shared/fangzy/data/st_multi_omics/simulation/HERGAST/simu1/rep{i}/adata1.h5ad")
sc.pp.highly_variable_genes(adata, n_top_genes=3000, subset=True)
sc.pp.scale(adata)

adata1 = sc.read_h5ad(f"/data/shared/fangzy/data/st_multi_omics/simulation/HERGAST/simu1/rep{i}/adata2.h5ad")
sc.pp.highly_variable_genes(adata1, n_top_genes=3000, subset=True)
sc.pp.scale(adata1)
smooth_x, adj = apply_sgc_pure(adata,  k_neighbors=6, n_layers=2)
smooth_x1, adj = apply_sgc_pure(adata1, k_neighbors=6, n_layers=2)
x_rna, x_atac, y, n_classes = process_adata_for_training(adata, adata1, label_key="ground_truth")

N_GENES = adata.shape[1]
N_ATAC = adata1.shape[1]
N_CLASSES = len(adata.obs["ground_truth"].unique())
max_epochs=10
data_module = spDataModule(x_rna, x_atac,  smooth_x, smooth_x1, adata.obsm["spatial"], y, batch_size=1024)
mask_prob = torch.full((N_GENES,), 0.4)
save_path = path+"simulation_test/"+str(i)+"/"
os.makedirs(save_path, exist_ok=True)
# Out:
# Seed set to 42
# /home/fangzy/miniconda3/envs/py3.10/lib/python3.10/functools.py:889: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/fangzy/miniconda3/envs/py3.10/lib/python3.10/functools.py:889: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)
# --- SGC Smoothing ---
# Using global kNN graph: k=6
# Average number of neighbors: 7.00
# --- SGC Smoothing ---
# Using global kNN graph: k=6
# Average number of neighbors: 7.00
#  - RNA shape: (79524, 3000)
#  - ATAC shape: (79524, 3000)
#  - Number of classes: 4

# %%
# ---------------------------
# 3. 初始化 Lightning Module
# --------------------------- 
model = spMAE_Lightning(
    num_feat1=N_GENES,
    num_feat2=N_ATAC,
    n_classes=N_CLASSES,
    hidden_size=128,
    lr=1e-3,
    mask_prob_rna=mask_prob,
    mask_prob_atac=mask_prob,
    epochs=max_epochs,
    mask_loss_weight=0.7,
    masked_data_weight=0.7,
    save_path=save_path
)

wandb_logger = WandbLogger(project="spMAE", name=f"simrep{i}_test", 
                        save_dir="/data/shared/fangzy/results/spMAE/wandb/")

# %%
trainer = pl.Trainer(
    max_epochs=max_epochs,
    accelerator='auto',
    devices=1,
    deterministic=True,
    logger=wandb_logger, 
    enable_checkpointing=False,
    enable_progress_bar=True,
    check_val_every_n_epoch=None
)
trainer.fit(model, data_module)
wandb.finish()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /home/fangzy/miniconda3/envs/py3.10/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:68: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/fangzy/.netrc.
# wandb: Currently logged in as: fangzhaoyu (sctrans) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.0
# Run data is saved locally in <code>/data/shared/fangzy/results/spMAE/wandb/wandb/run-20260611_221751-hpoiid6l</code>
# Syncing run <strong><a href='https://wandb.ai/sctrans/spMAE/runs/hpoiid6l' target="_blank">simrep0_test</a></strong> to <a href='https://wandb.ai/sctrans/spMAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sctrans/spMAE' target="_blank">https://wandb.ai/sctrans/spMAE</a>
#  View run at <a href='https://wandb.ai/sctrans/spMAE/runs/hpoiid6l' target="_blank">https://wandb.ai/sctrans/spMAE/runs/hpoiid6l</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name         ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model        │ spMAE              │ 21.3 M │ train │     0 │
# │ 1 │ clip_loss_fn │ CrossModalCLIPLoss │      1 │ train │     0 │
# └───┴──────────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 21.3 M
# Non-trainable params: 0
# Total params: 21.3 M
# Total estimated model params size (MB): 85
# Modules in train mode: 31
# Modules in eval mode: 0
# Total FLOPs: 0
# /home/fangzy/miniconda3/envs/py3.10/lib/python3.10/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /home/fangzy/miniconda3/envs/py3.10/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=111` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train/loss_atac_mask</td><td>█▄▄▄▃▃▂▂▁▁</td></tr><tr><td>train/loss_atac_recon</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_clip</td><td>█▅▄▃▃▂▂▂▁▁</td></tr><tr><td>train/loss_rna_mask</td><td>█▄▄▄▃▃▂▂▁▁</td></tr><tr><td>train/loss_rna_recon</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_total</td><td>█▄▄▃▃▂▂▂▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train/loss_atac_mask</td><td>0.31817</td></tr><tr><td>train/loss_atac_recon</td><td>0.00983</td></tr><tr><td>train/loss_clip</td><td>0.65546</td></tr><tr><td>train/loss_rna_mask</td><td>0.3195</td></tr><tr><td>train/loss_rna_recon</td><td>0.0098</td></tr><tr><td>train/loss_total</td><td>1.31276</td></tr><tr><td>trainer/global_step</td><td>769</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">simrep0_test</strong> at: <a href='https://wandb.ai/sctrans/spMAE/runs/hpoiid6l' target="_blank">https://wandb.ai/sctrans/spMAE/runs/hpoiid6l</a><br> View project at: <a href='https://wandb.ai/sctrans/spMAE' target="_blank">https://wandb.ai/sctrans/spMAE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/data/shared/fangzy/results/spMAE/wandb/wandb/run-20260611_221751-hpoiid6l/logs</code>

# %%
features = model.get_latents(data_module.val_dataloader()) 
latent_fused = features['latent_fused']
labels = y
spatial = adata.obsm["spatial"]

# %%
# PCA + mclust
all_latents_pca = dopca(latent_fused, dim=10)
pred_labels_mclust = mclust_R(all_latents_pca, N_CLASSES)


if (labels >= 0).any():
    nmi1, ari1, hom1, ami1 = evaluate(labels, pred_labels_mclust)
    print(f" ARI: {ari1:.4f}")
# Out:
# fitting ...
#   |======================================================================| 100%
#  ARI: 0.9523

# %%
adata.obs["pred_spMAE"] = pred_labels_mclust
adata.obs["pred_spMAE"] = adata.obs["pred_spMAE"].astype("category")

# %%
sc.pl.embedding(adata, basis="spatial", color=["pred_spMAE", "ground_truth"], size=3)
